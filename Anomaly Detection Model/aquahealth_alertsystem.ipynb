# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
file1 = "scalar_1215309_191a_0eca_90dc.csv" #Prince Rupert Atlin Terminal Station Conductivity Temperature Depth (May 1st, 2024 to May 2nd, 2024)
file2 = "scalar_1215311_9e77_a900_b059.csv" #Prince Rupert Atlin Terminal Station Oxygen Sensor Deployed (May 1st, 2024 to May 2nd, 2024)

# %%
df1_cols = ['timeseries_id',
            'time',
            'Sound_Speed',
            'turbidity',
            'Temperature',
            'density',
            'cond',
            'salinity',
            'pressure',
            'latitude',
            'longitude',
            'depth']

df2_cols = ['timeseries_id',
            'time',
            'oxygen_corrected',
            'oxygen_uncorrected',
            'latitude',
            'longitude',
            'depth']

# %%
df1 = pd.read_csv(file1,header=None,skiprows=2,names=df1_cols)
df1.head(5)
# Out:
#     timeseries_id                      time  Sound_Speed  turbidity  \
# 0  scalar_1215309  2024-05-01T00:39:03.643Z  1480.276013      -0.16
# 1  scalar_1215309  2024-05-01T00:39:04.641Z  1480.308081      -0.07
# 2  scalar_1215309  2024-05-01T00:39:05.642Z  1480.372628       0.02
# 3  scalar_1215309  2024-05-01T00:39:06.641Z  1480.412788       0.21
# 4  scalar_1215309  2024-05-01T00:39:07.641Z  1480.393826       0.25
#
#    Temperature   density    cond   salinity  pressure  latitude  longitude  \
# 0      282.200  0.001023  3.2238  29.858658     12.04  54.31877 -130.32105
# 1      282.210  0.001023  3.2242  29.854378     12.04  54.31877 -130.32105
# 2      282.233  0.001023  3.2244  29.837168     12.03  54.31877 -130.32105
# 3      282.246  0.001023  3.2248  29.830385     12.03  54.31877 -130.32105
# 4      282.238  0.001023  3.2250  29.839124     12.04  54.31877 -130.32105
#
#    depth
# 0   11.0
# 1   11.0
# 2   11.0
# 3   11.0
# 4   11.0

# %%
df2 = pd.read_csv(file2,header=None,skiprows=2,names=df2_cols)
df2.head(5)
# Out:
#     timeseries_id                      time  oxygen_corrected  \
# 0  scalar_1215311  2024-05-01T05:24:41.671Z          6.627360
# 1  scalar_1215311  2024-05-01T05:24:42.671Z          6.632853
# 2  scalar_1215311  2024-05-01T05:24:43.671Z          6.632757
# 3  scalar_1215311  2024-05-01T05:24:44.671Z          6.632620
# 4  scalar_1215311  2024-05-01T05:24:45.671Z          6.630587
#
#    oxygen_uncorrected  latitude  longitude  depth
# 0            8.045374  54.31877 -130.32105   11.0
# 1            8.052091  54.31877 -130.32105   11.0
# 2            8.052091  54.31877 -130.32105   11.0
# 3            8.052091  54.31877 -130.32105   11.0
# 4            8.049852  54.31877 -130.32105   11.0

# %%
df1['time'] = pd.to_datetime(df1['time'])
df2['time'] = pd.to_datetime(df2['time'])

# %%
#Converting the Temperature from Kelvin to Celcius
df1['Temperature'] = df1['Temperature'] - 273.15

# %%
df1['Temperature'].head(5)
# Out:
# 0    9.050
# 1    9.060
# 2    9.083
# 3    9.096
# 4    9.088
# Name: Temperature, dtype: float64

# %%
merged = pd.merge_asof(df1.sort_values('time'), df2.sort_values('time'), on='time', direction='nearest')

# %%
merged.columns
# Out:
# Index(['timeseries_id_x', 'time', 'Sound_Speed', 'turbidity', 'Temperature',
#        'density', 'cond', 'salinity', 'pressure', 'latitude_x', 'longitude_x',
#        'depth_x', 'timeseries_id_y', 'oxygen_corrected', 'oxygen_uncorrected',
#        'latitude_y', 'longitude_y', 'depth_y'],
#       dtype='object')

# %%
features = merged[['Temperature', 'salinity', 'oxygen_corrected']].dropna()

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
model = IsolationForest(contamination=0.05, random_state=42)
merged.loc[features.index, 'Alert'] = model.fit_predict(scaled_features)
merged['Alert'] = merged['Alert'].map({1: 'Normal', -1: 'Anomaly Detected'})

# %%
output = merged[['time', 'Temperature', 'salinity', 'oxygen_corrected', 'Alert']]

# %%
output.head(5)
# Out:
#                               time  Temperature   salinity  oxygen_corrected  \
# 0 2024-05-01 00:39:03.643000+00:00        9.050  29.858658           6.62736
# 1 2024-05-01 00:39:04.641000+00:00        9.060  29.854378           6.62736
# 2 2024-05-01 00:39:05.642000+00:00        9.083  29.837168           6.62736
# 3 2024-05-01 00:39:06.641000+00:00        9.096  29.830385           6.62736
# 4 2024-05-01 00:39:07.641000+00:00        9.088  29.839124           6.62736
#
#     Alert
# 0  Normal
# 1  Normal
# 2  Normal
# 3  Normal
# 4  Normal

# %%
output[output['Alert']=='Anomaly Detected'].head(20)
# Out:
#                                   time  Temperature   salinity  \
# 60797 2024-05-02 05:41:59.461000+00:00        9.392  29.422826
# 60798 2024-05-02 05:42:00.461000+00:00        9.418  29.400468
# 60799 2024-05-02 05:42:01.460000+00:00        9.419  29.396610
# 60800 2024-05-02 05:42:02.460000+00:00        9.518  29.307505
# 60801 2024-05-02 05:42:03.460000+00:00        9.547  29.286877
# 60802 2024-05-02 05:42:04.460000+00:00        9.543  29.289124
# 60803 2024-05-02 05:42:05.460000+00:00        9.531  29.294874
# 60804 2024-05-02 05:42:06.459000+00:00        9.533  29.292232
# 60805 2024-05-02 05:42:07.459000+00:00        9.526  29.296932
# 60806 2024-05-02 05:42:08.459000+00:00        9.561  29.266373
# 60807 2024-05-02 05:42:09.459000+00:00        9.581  29.251101
# 60808 2024-05-02 05:42:10.459000+00:00        9.593  29.241333
# 60809 2024-05-02 05:42:11.459000+00:00        9.600  29.235643
# 60810 2024-05-02 05:42:12.459000+00:00        9.608  29.225105
# 60811 2024-05-02 05:42:13.459000+00:00        9.582  29.246247
# 60812 2024-05-02 05:42:14.459000+00:00        9.616  29.216587
# 60813 2024-05-02 05:42:15.458000+00:00        9.618  29.216978
# 60814 2024-05-02 05:42:16.458000+00:00        9.589  29.238533
# 60815 2024-05-02 05:42:17.458000+00:00        9.577  29.249311
# 60816 2024-05-02 05:42:18.458000+00:00        9.556  29.265401
#
#        oxygen_corrected             Alert
# 60797          6.609366  Anomaly Detected
# 60798          6.610573  Anomaly Detected
# 60799          6.610743  Anomaly Detected
# 60800          6.617351  Anomaly Detected
# 60801          6.618510  Anomaly Detected
# 60802          6.618378  Anomaly Detected
# 60803          6.636588  Anomaly Detected
# 60804          6.636720  Anomaly Detected
# 60805          6.636452  Anomaly Detected
# 60806          6.652961  Anomaly Detected
# 60807          6.653806  Anomaly Detected
# 60808          6.654343  Anomaly Detected
# 60809          6.660226  Anomaly Detected
# 60810          6.660754  Anomaly Detected
# 60811          6.659599  Anomaly Detected
# 60812          6.670489  Anomaly Detected
# 60813          6.670492  Anomaly Detected
# 60814          6.669289  Anomaly Detected
# 60815          6.692863  Anomaly Detected
# 60816          6.691965  Anomaly Detected

# %%
anomaly_scores = model.decision_function(scaled_features)
merged.loc[features.index, 'Anomaly_Score'] = anomaly_scores

# %%
min_score = merged['Anomaly_Score'].min()
max_score = merged['Anomaly_Score'].max()
merged['Risk_Score'] = merged['Anomaly_Score'].apply(
    lambda x: round(100 * (1 - (x - min_score) / (max_score - min_score)), 2)
)

# %%
def interpret_anomaly(row):
    reasons = []
    if row['Temperature'] > 20:
        reasons.append("High temperature")
    if row['oxygen_corrected'] < 5:
        reasons.append("Low dissolved oxygen")
    if row['salinity'] < 28 or row['salinity'] > 35:
        reasons.append("Salinity out of range")
    return "; ".join(reasons) if reasons else "Unusual pattern detected (no single variable outside safe range)"

# %%
def generate_detailed_alert(row):
    if row['Alert'] == 'Anomaly Detected':
        return f"Risk Score: {row['Risk_Score']} | {interpret_anomaly(row)}"
    else:
        return "Normal"

# %%
merged['Detailed_Alert'] = merged.apply(generate_detailed_alert, axis=1)

# %%
enhanced_sample = merged[['time', 'Temperature', 'salinity', 'oxygen_corrected', 'Anomaly_Score', 'Detailed_Alert']].head(10)

# %%
merged[['Alert','Detailed_Alert']][merged['Alert']=='Anomaly Detected'].head(30)
# Out:
#                   Alert                                     Detailed_Alert
# 60797  Anomaly Detected  Risk Score: 49.45 | Unusual pattern detected (...
# 60798  Anomaly Detected  Risk Score: 49.67 | Unusual pattern detected (...
# 60799  Anomaly Detected  Risk Score: 49.9 | Unusual pattern detected (n...
# 60800  Anomaly Detected  Risk Score: 56.87 | Unusual pattern detected (...
# 60801  Anomaly Detected  Risk Score: 61.3 | Unusual pattern detected (n...
# 60802  Anomaly Detected  Risk Score: 60.14 | Unusual pattern detected (...
# 60803  Anomaly Detected  Risk Score: 58.22 | Unusual pattern detected (...
# 60804  Anomaly Detected  Risk Score: 58.6 | Unusual pattern detected (n...
# 60805  Anomaly Detected  Risk Score: 57.5 | Unusual pattern detected (n...
# 60806  Anomaly Detected  Risk Score: 63.26 | Unusual pattern detected (...
# 60807  Anomaly Detected  Risk Score: 63.54 | Unusual pattern detected (...
# 60808  Anomaly Detected  Risk Score: 64.38 | Unusual pattern detected (...
# 60809  Anomaly Detected  Risk Score: 65.94 | Unusual pattern detected (...
# 60810  Anomaly Detected  Risk Score: 66.45 | Unusual pattern detected (...
# 60811  Anomaly Detected  Risk Score: 63.54 | Unusual pattern detected (...
# 60812  Anomaly Detected  Risk Score: 65.81 | Unusual pattern detected (...
# 60813  Anomaly Detected  Risk Score: 65.81 | Unusual pattern detected (...
# 60814  Anomaly Detected  Risk Score: 63.64 | Unusual pattern detected (...
# 60815  Anomaly Detected  Risk Score: 63.58 | Unusual pattern detected (...
# 60816  Anomaly Detected  Risk Score: 61.27 | Unusual pattern detected (...
# 60817  Anomaly Detected  Risk Score: 57.23 | Unusual pattern detected (...
# 60818  Anomaly Detected  Risk Score: 59.28 | Unusual pattern detected (...
# 60819  Anomaly Detected  Risk Score: 63.83 | Unusual pattern detected (...
# 60820  Anomaly Detected  Risk Score: 62.74 | Unusual pattern detected (...
# 60821  Anomaly Detected  Risk Score: 61.91 | Unusual pattern detected (...
# 60822  Anomaly Detected  Risk Score: 64.1 | Unusual pattern detected (n...
# 60823  Anomaly Detected  Risk Score: 61.95 | Unusual pattern detected (...
# 60824  Anomaly Detected  Risk Score: 58.93 | Unusual pattern detected (...
# 60825  Anomaly Detected  Risk Score: 62.39 | Unusual pattern detected (...
# 60826  Anomaly Detected  Risk Score: 63.74 | Unusual pattern detected (...

# %%
merged[merged['Alert']=='Anomaly Detected'].head(1)
# Out:
#       timeseries_id_x                             time  Sound_Speed  \
# 60797  scalar_1215309 2024-05-02 05:41:59.461000+00:00  1481.019566
#
#        turbidity  Temperature   density    cond   salinity  pressure  \
# 60797        0.8        9.392  0.001023  3.2089  29.422826     12.33
#
#        latitude_x  ...  timeseries_id_y  oxygen_corrected oxygen_uncorrected  \
# 60797    54.31877  ...   scalar_1215311          6.609366           7.975959
#
#        latitude_y  longitude_y  depth_y             Alert  Anomaly_Score  \
# 60797    54.31877   -130.32105     11.0  Anomaly Detected      -0.002483
#
#       Risk_Score                                     Detailed_Alert
# 60797      49.45  Risk Score: 49.45 | Unusual pattern detected (...
#
# [1 rows x 22 columns]

# %%
import joblib

joblib.dump(model, "aquahealth_anomalydetection_model.pkl")
joblib.dump(scaler, "aquahealth_feature_scaler.pkl")
# Out:
# ['aquahealth_feature_scaler.pkl']
